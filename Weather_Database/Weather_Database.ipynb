# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/kanikoliji/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/kanikoliji/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3e268cd7344d59357413ea2c5e527d25

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current_Description": city_description,})

    # If an error is experienced, skip the city.
    except:
        print("city not found. skipping....")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | marcona
# city not found. skipping....
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | zhireken
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | amga
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | arcos
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | kopervik
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | neuquen
# Processing Record 18 of Set 1 | kloulklubed
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | puerto escondido
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | mgandu
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | leeton
# Processing Record 28 of Set 1 | kefamenanu
# Processing Record 29 of Set 1 | tomatlan
# Processing Record 30 of Set 1 | guerrero negro
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | taolanaro
# city not found. skipping....
# Processing Record 34 of Set 1 | lagoa
# Processing Record 35 of Set 1 | nam dinh
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | torres
# Processing Record 40 of Set 1 | broken hill
# Processing Record 41 of Set 1 | general roca
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | kysyl-syr
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | porto nacional
# Processing Record 48 of Set 1 | pisco
# Processing Record 49 of Set 1 | hamilton
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | mersing
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | tongliao
# Processing Record 7 of Set 2 | samarai
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | belushya guba
# city not found. skipping....
# Processing Record 10 of Set 2 | buluang
# Processing Record 11 of Set 2 | meyungs
# city not found. skipping....
# Processing Record 12 of Set 2 | gawler
# Processing Record 13 of Set 2 | bowen
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | shache
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | ampanihy
# Processing Record 20 of Set 2 | teahupoo
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | attawapiskat
# city not found. skipping....
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | sao sepe
# Processing Record 25 of Set 2 | duz
# city not found. skipping....
# Processing Record 26 of Set 2 | ksenyevka
# city not found. skipping....
# Processing Record 27 of Set 2 | murdochville
# Processing Record 28 of Set 2 | inhambane
# Processing Record 29 of Set 2 | vila
# Processing Record 30 of Set 2 | igrim
# Processing Record 31 of Set 2 | sukabumi
# Processing Record 32 of Set 2 | port hedland
# Processing Record 33 of Set 2 | ojinaga
# Processing Record 34 of Set 2 | umm lajj
# Processing Record 35 of Set 2 | mabaruma
# Processing Record 36 of Set 2 | maldonado
# Processing Record 37 of Set 2 | omsukchan
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | geraldton
# Processing Record 40 of Set 2 | ust-tarka
# Processing Record 41 of Set 2 | yomitan
# city not found. skipping....
# Processing Record 42 of Set 2 | enshi
# Processing Record 43 of Set 2 | sola
# Processing Record 44 of Set 2 | jardim
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | husavik
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | mahebourg
# Processing Record 1 of Set 3 | palabuhanratu
# city not found. skipping....
# Processing Record 2 of Set 3 | illoqqortoormiut
# city not found. skipping....
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | falealupo
# city not found. skipping....
# Processing Record 5 of Set 3 | coihaique
# Processing Record 6 of Set 3 | colon
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | port-cartier
# Processing Record 9 of Set 3 | opuwo
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | makakilo city
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | mehamn
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | hue
# Processing Record 16 of Set 3 | khalilabad
# Processing Record 17 of Set 3 | comodoro rivadavia
# Processing Record 18 of Set 3 | clyde river
# Processing Record 19 of Set 3 | berdigestyakh
# Processing Record 20 of Set 3 | tsihombe
# city not found. skipping....
# Processing Record 21 of Set 3 | safaga
# Processing Record 22 of Set 3 | kuvshinovo
# Processing Record 23 of Set 3 | gizo
# Processing Record 24 of Set 3 | kota bahru
# Processing Record 25 of Set 3 | sabzevar
# Processing Record 26 of Set 3 | troy
# Processing Record 27 of Set 3 | mys shmidta
# city not found. skipping....
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | ungra
# Processing Record 30 of Set 3 | udachnyy
# Processing Record 31 of Set 3 | miles city
# Processing Record 32 of Set 3 | kadykchan
# city not found. skipping....
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | lazaro cardenas
# Processing Record 35 of Set 3 | liku
# Processing Record 36 of Set 3 | pavlodar
# Processing Record 37 of Set 3 | ancud
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | khuzhir
# Processing Record 40 of Set 3 | leshukonskoye
# Processing Record 41 of Set 3 | dingle
# Processing Record 42 of Set 3 | pakxe
# Processing Record 43 of Set 3 | taoudenni
# Processing Record 44 of Set 3 | cabo san lucas
# Processing Record 45 of Set 3 | luganville
# Processing Record 46 of Set 3 | mayumba
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | ust-nera
# Processing Record 49 of Set 3 | kavaratti
# Processing Record 50 of Set 3 | barentsburg
# city not found. skipping....
# Processing Record 1 of Set 4 | pandamatenga
# Processing Record 2 of Set 4 | miri
# Processing Record 3 of Set 4 | narsaq
# Processing Record 4 of Set 4 | finschhafen
# Processing Record 5 of Set 4 | nicoya
# Processing Record 6 of Set 4 | grand-lahou
# Processing Record 7 of Set 4 | kikwit
# Processing Record 8 of Set 4 | pio ix
# Processing Record 9 of Set 4 | lavrentiya
# Processing Record 10 of Set 4 | laguna
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | karasjok
# Processing Record 13 of Set 4 | norman wells
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | beihai
# Processing Record 16 of Set 4 | axim
# Processing Record 17 of Set 4 | pakwach
# city not found. skipping....
# Processing Record 18 of Set 4 | katherine
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | gigmoto
# Processing Record 21 of Set 4 | cidreira
# Processing Record 22 of Set 4 | karaul
# city not found. skipping....
# Processing Record 23 of Set 4 | butaritari
# Processing Record 24 of Set 4 | tahta
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | sao filipe
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | mar del plata
# Processing Record 29 of Set 4 | vaitupu
# city not found. skipping....
# Processing Record 30 of Set 4 | coquimbo
# Processing Record 31 of Set 4 | bogorodskoye
# Processing Record 32 of Set 4 | ilulissat
# Processing Record 33 of Set 4 | ginir
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | san cristobal
# Processing Record 37 of Set 4 | lata
# Processing Record 38 of Set 4 | hervey bay
# Processing Record 39 of Set 4 | samusu
# city not found. skipping....
# Processing Record 40 of Set 4 | nizhniy bestyakh
# Processing Record 41 of Set 4 | imbituba
# Processing Record 42 of Set 4 | athabasca
# Processing Record 43 of Set 4 | xai-xai
# Processing Record 44 of Set 4 | mazagao
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | ciudad bolivar
# Processing Record 47 of Set 4 | caravelas
# Processing Record 48 of Set 4 | kachikau
# city not found. skipping....
# Processing Record 49 of Set 4 | asfi
# Processing Record 50 of Set 4 | edd
# Processing Record 1 of Set 5 | moyale
# Processing Record 2 of Set 5 | ngukurr
# city not found. skipping....
# Processing Record 3 of Set 5 | saint-augustin
# Processing Record 4 of Set 5 | marzuq
# Processing Record 5 of Set 5 | dwarka
# Processing Record 6 of Set 5 | cherskiy
# Processing Record 7 of Set 5 | vigeland
# Processing Record 8 of Set 5 | tommot
# Processing Record 9 of Set 5 | nizhniy kuranakh
# Processing Record 10 of Set 5 | tarnos
# Processing Record 11 of Set 5 | bengkulu
# Processing Record 12 of Set 5 | sao raimundo das mangabeiras
# Processing Record 13 of Set 5 | marang
# Processing Record 14 of Set 5 | felipe carrillo puerto
# Processing Record 15 of Set 5 | byron bay
# Processing Record 16 of Set 5 | sorland
# Processing Record 17 of Set 5 | port macquarie
# Processing Record 18 of Set 5 | hihifo
# city not found. skipping....
# Processing Record 19 of Set 5 | te anau
# Processing Record 20 of Set 5 | manokwari
# Processing Record 21 of Set 5 | kikinda
# Processing Record 22 of Set 5 | severo-kurilsk
# Processing Record 23 of Set 5 | lakes entrance
# Processing Record 24 of Set 5 | beira
# Processing Record 25 of Set 5 | saldanha
# Processing Record 26 of Set 5 | najran
# Processing Record 27 of Set 5 | salalah
# Processing Record 28 of Set 5 | alexandria
# Processing Record 29 of Set 5 | koslan
# Processing Record 30 of Set 5 | matara
# Processing Record 31 of Set 5 | bolshaya martynovka
# Processing Record 32 of Set 5 | kot putli
# city not found. skipping....
# Processing Record 33 of Set 5 | ponta delgada
# Processing Record 34 of Set 5 | bubaque
# Processing Record 35 of Set 5 | tabas
# Processing Record 36 of Set 5 | sarangani
# Processing Record 37 of Set 5 | orativ
# Processing Record 38 of Set 5 | santa cruz
# Processing Record 39 of Set 5 | kutum
# Processing Record 40 of Set 5 | xichang
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | lucapa
# Processing Record 43 of Set 5 | utiroa
# city not found. skipping....
# Processing Record 44 of Set 5 | sovetskaya gavan
# Processing Record 45 of Set 5 | krasnoselkup
# Processing Record 46 of Set 5 | shelby
# Processing Record 47 of Set 5 | port hawkesbury
# Processing Record 48 of Set 5 | alyangula
# Processing Record 49 of Set 5 | estelle
# Processing Record 50 of Set 5 | grindavik
# Processing Record 1 of Set 6 | januaria
# Processing Record 2 of Set 6 | sai buri
# Processing Record 3 of Set 6 | namatanai
# Processing Record 4 of Set 6 | loa janan
# Processing Record 5 of Set 6 | tabiauea
# city not found. skipping....
# Processing Record 6 of Set 6 | constantine
# Processing Record 7 of Set 6 | buraydah
# Processing Record 8 of Set 6 | komsomolskiy
# Processing Record 9 of Set 6 | kyra
# Processing Record 10 of Set 6 | volksrust
# Processing Record 11 of Set 6 | alta floresta
# Processing Record 12 of Set 6 | mopti
# Processing Record 13 of Set 6 | katsuura
# Processing Record 14 of Set 6 | guilin
# Processing Record 15 of Set 6 | zhigansk
# Processing Record 16 of Set 6 | baghdad
# Processing Record 17 of Set 6 | aklavik
# Processing Record 18 of Set 6 | talnakh
# Processing Record 19 of Set 6 | haimen
# Processing Record 20 of Set 6 | alice springs
# Processing Record 21 of Set 6 | ewa beach
# Processing Record 22 of Set 6 | tasiilaq
# Processing Record 23 of Set 6 | liepaja
# Processing Record 24 of Set 6 | amderma
# city not found. skipping....
# Processing Record 25 of Set 6 | bakel
# Processing Record 26 of Set 6 | buta
# Processing Record 27 of Set 6 | chapais
# Processing Record 28 of Set 6 | eydhafushi
# Processing Record 29 of Set 6 | kilindoni
# Processing Record 30 of Set 6 | mantua
# Processing Record 31 of Set 6 | okoneshnikovo
# Processing Record 32 of Set 6 | hasaki
# Processing Record 33 of Set 6 | vestmannaeyjar
# Processing Record 34 of Set 6 | bathsheba
# Processing Record 35 of Set 6 | villaviciosa
# Processing Record 36 of Set 6 | wildomar
# Processing Record 37 of Set 6 | locri
# Processing Record 38 of Set 6 | council bluffs
# Processing Record 39 of Set 6 | vanimo
# Processing Record 40 of Set 6 | patacamaya
# Processing Record 41 of Set 6 | quatre cocos
# Processing Record 42 of Set 6 | dongli
# Processing Record 43 of Set 6 | matagami
# Processing Record 44 of Set 6 | bolungarvik
# city not found. skipping....
# Processing Record 45 of Set 6 | gat
# Processing Record 46 of Set 6 | saskylakh
# Processing Record 47 of Set 6 | deputatskiy
# Processing Record 48 of Set 6 | malakal
# Processing Record 49 of Set 6 | muzhi
# Processing Record 50 of Set 6 | zhengjiatun
# Processing Record 1 of Set 7 | parrita
# Processing Record 2 of Set 7 | chumikan
# Processing Record 3 of Set 7 | kulhudhuffushi
# Processing Record 4 of Set 7 | sinnamary
# Processing Record 5 of Set 7 | tuktoyaktuk
# Processing Record 6 of Set 7 | isangel
# Processing Record 7 of Set 7 | kiama
# Processing Record 8 of Set 7 | doha
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | asau
# Processing Record 11 of Set 7 | saint-georges
# Processing Record 12 of Set 7 | san juan
# Processing Record 13 of Set 7 | sentyabrskiy
# city not found. skipping....
# Processing Record 14 of Set 7 | aflu
# city not found. skipping....
# Processing Record 15 of Set 7 | port elizabeth
# Processing Record 16 of Set 7 | kjollefjord
# Processing Record 17 of Set 7 | arandis
# Processing Record 18 of Set 7 | truth or consequences
# Processing Record 19 of Set 7 | maridi
# Processing Record 20 of Set 7 | avera
# Processing Record 21 of Set 7 | santiago de chuco
# Processing Record 22 of Set 7 | mancio lima
# Processing Record 23 of Set 7 | bambous virieux
# Processing Record 24 of Set 7 | sabha
# Processing Record 25 of Set 7 | abha
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | joshimath
# Processing Record 28 of Set 7 | machacamarca
# Processing Record 29 of Set 7 | garden city
# Processing Record 30 of Set 7 | brownwood
# Processing Record 31 of Set 7 | walvis bay
# Processing Record 32 of Set 7 | marawi
# Processing Record 33 of Set 7 | porto novo
# Processing Record 34 of Set 7 | mixtequilla
# city not found. skipping....
# Processing Record 35 of Set 7 | belle fourche
# Processing Record 36 of Set 7 | ribeira grande
# Processing Record 37 of Set 7 | sabang
# Processing Record 38 of Set 7 | louisbourg
# city not found. skipping....
# Processing Record 39 of Set 7 | tura
# Processing Record 40 of Set 7 | naifaru
# Processing Record 41 of Set 7 | robertson
# Processing Record 42 of Set 7 | mwense
# Processing Record 43 of Set 7 | suisun city
# Processing Record 44 of Set 7 | lar gerd
# city not found. skipping....
# Processing Record 45 of Set 7 | akdepe
# Processing Record 46 of Set 7 | vila franca do campo
# Processing Record 47 of Set 7 | tuatapere
# Processing Record 48 of Set 7 | bilma
# Processing Record 49 of Set 7 | ferkessedougou
# Processing Record 50 of Set 7 | kudahuvadhoo
# Processing Record 1 of Set 8 | newport
# Processing Record 2 of Set 8 | maniitsoq
# Processing Record 3 of Set 8 | tatarsk
# Processing Record 4 of Set 8 | ust-kamchatsk
# city not found. skipping....
# Processing Record 5 of Set 8 | vung tau
# Processing Record 6 of Set 8 | pitimbu
# Processing Record 7 of Set 8 | vardo
# Processing Record 8 of Set 8 | nyagan
# Processing Record 9 of Set 8 | tiksi
# Processing Record 10 of Set 8 | wewak
# Processing Record 11 of Set 8 | huntsville
# Processing Record 12 of Set 8 | portland
# Processing Record 13 of Set 8 | pacific grove
# Processing Record 14 of Set 8 | telma
# Processing Record 15 of Set 8 | san francisco
# Processing Record 16 of Set 8 | vyazniki
# Processing Record 17 of Set 8 | arrah
# Processing Record 18 of Set 8 | sao gabriel da cachoeira
# Processing Record 19 of Set 8 | yar-sale
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | chifeng
# Processing Record 22 of Set 8 | klyuchi
# Processing Record 23 of Set 8 | wellington
# Processing Record 24 of Set 8 | sataua
# city not found. skipping....
# Processing Record 25 of Set 8 | orissaare
# Processing Record 26 of Set 8 | stykkisholmur
# Processing Record 27 of Set 8 | soyo
# Processing Record 28 of Set 8 | nishihara
# Processing Record 29 of Set 8 | nome
# Processing Record 30 of Set 8 | nizwa
# Processing Record 31 of Set 8 | kargat
# Processing Record 32 of Set 8 | port augusta
# Processing Record 33 of Set 8 | rio grande
# Processing Record 34 of Set 8 | kashi
# Processing Record 35 of Set 8 | klaksvik
# Processing Record 36 of Set 8 | broome
# Processing Record 37 of Set 8 | biskamzha
# Processing Record 38 of Set 8 | khairpur nathan shah
# Processing Record 39 of Set 8 | nizhniy baskunchak
# Processing Record 40 of Set 8 | at-bashi
# Processing Record 41 of Set 8 | kalmunai
# Processing Record 42 of Set 8 | yulara
# Processing Record 43 of Set 8 | kodinsk
# Processing Record 44 of Set 8 | la ronge
# Processing Record 45 of Set 8 | ormara
# Processing Record 46 of Set 8 | anadyr
# Processing Record 47 of Set 8 | achisay
# city not found. skipping....
# Processing Record 48 of Set 8 | yeppoon
# Processing Record 49 of Set 8 | hovd
# Processing Record 50 of Set 8 | bobcaygeon
# Processing Record 1 of Set 9 | cockburn town
# Processing Record 2 of Set 9 | huilong
# Processing Record 3 of Set 9 | henties bay
# Processing Record 4 of Set 9 | xining
# Processing Record 5 of Set 9 | banda aceh
# Processing Record 6 of Set 9 | maningrida
# Processing Record 7 of Set 9 | huzhou
# Processing Record 8 of Set 9 | trenggalek
# Processing Record 9 of Set 9 | saint-leu
# Processing Record 10 of Set 9 | arroyo
# Processing Record 11 of Set 9 | faya
# Processing Record 12 of Set 9 | strezhevoy
# Processing Record 13 of Set 9 | genhe
# Processing Record 14 of Set 9 | lodwar
# Processing Record 15 of Set 9 | stanghelle
# Processing Record 16 of Set 9 | kamenskoye
# city not found. skipping....
# Processing Record 17 of Set 9 | codrington
# Processing Record 18 of Set 9 | pilar
# Processing Record 19 of Set 9 | maragogi
# Processing Record 20 of Set 9 | northam
# Processing Record 21 of Set 9 | oranjemund
# Processing Record 22 of Set 9 | gabu
# Processing Record 23 of Set 9 | kokopo
# Processing Record 24 of Set 9 | toora-khem
# Processing Record 25 of Set 9 | agua branca
# Processing Record 26 of Set 9 | imatra
# Processing Record 27 of Set 9 | tianpeng
# Processing Record 28 of Set 9 | tiznit
# Processing Record 29 of Set 9 | evensk
# Processing Record 30 of Set 9 | saryg-sep
# Processing Record 31 of Set 9 | sorong
# Processing Record 32 of Set 9 | verkhnyaya inta
# Processing Record 33 of Set 9 | boende
# Processing Record 34 of Set 9 | ust-kulom
# Processing Record 35 of Set 9 | taltal
# Processing Record 36 of Set 9 | las juntas
# Processing Record 37 of Set 9 | moctezuma
# Processing Record 38 of Set 9 | payo
# Processing Record 39 of Set 9 | leningradskiy
# Processing Record 40 of Set 9 | pangnirtung
# Processing Record 41 of Set 9 | corinth
# Processing Record 42 of Set 9 | roma
# Processing Record 43 of Set 9 | derzhavinsk
# Processing Record 44 of Set 9 | aubagne
# Processing Record 45 of Set 9 | praya
# Processing Record 46 of Set 9 | marshalltown
# Processing Record 47 of Set 9 | provideniya
# Processing Record 48 of Set 9 | kidal
# Processing Record 49 of Set 9 | xinzhou
# Processing Record 50 of Set 9 | meulaboh
# Processing Record 1 of Set 10 | malanje
# Processing Record 2 of Set 10 | makat
# Processing Record 3 of Set 10 | ozark
# Processing Record 4 of Set 10 | isla vista
# Processing Record 5 of Set 10 | saint anthony
# Processing Record 6 of Set 10 | veraval
# Processing Record 7 of Set 10 | umzimvubu
# city not found. skipping....
# Processing Record 8 of Set 10 | nemuro
# Processing Record 9 of Set 10 | shimoda
# Processing Record 10 of Set 10 | poum
# Processing Record 11 of Set 10 | manaure
# Processing Record 12 of Set 10 | pandan
# Processing Record 13 of Set 10 | emet
# Processing Record 14 of Set 10 | pyapon
# Processing Record 15 of Set 10 | itarema
# Processing Record 16 of Set 10 | jaisalmer
# Processing Record 17 of Set 10 | ketchikan
# Processing Record 18 of Set 10 | naryan-mar
# Processing Record 19 of Set 10 | sao joao da barra
# Processing Record 20 of Set 10 | mount isa
# Processing Record 21 of Set 10 | kununurra
# Processing Record 22 of Set 10 | qaqortoq
# Processing Record 23 of Set 10 | rio gallegos
# Processing Record 24 of Set 10 | guiratinga
# Processing Record 25 of Set 10 | grand river south east
# city not found. skipping....
# Processing Record 26 of Set 10 | wanaka
# Processing Record 27 of Set 10 | sakakah
# Processing Record 28 of Set 10 | constancia
# Processing Record 29 of Set 10 | padang
# Processing Record 30 of Set 10 | gornopravdinsk
# Processing Record 31 of Set 10 | ballina
# Processing Record 32 of Set 10 | noumea
# Processing Record 33 of Set 10 | north platte
# Processing Record 34 of Set 10 | kuchinarai
# Processing Record 35 of Set 10 | macaboboni
# city not found. skipping....
# Processing Record 36 of Set 10 | kuche
# city not found. skipping....
# Processing Record 37 of Set 10 | vostok
# Processing Record 38 of Set 10 | vao
# Processing Record 39 of Set 10 | darhan
# Processing Record 40 of Set 10 | wanning
# Processing Record 41 of Set 10 | doka
# Processing Record 42 of Set 10 | yasothon
# Processing Record 43 of Set 10 | artesia
# Processing Record 44 of Set 10 | tamandare
# Processing Record 45 of Set 10 | adrar
# Processing Record 46 of Set 10 | college
# Processing Record 47 of Set 10 | haapiti
# Processing Record 48 of Set 10 | bambanglipuro
# Processing Record 49 of Set 10 | merauke
# Processing Record 50 of Set 10 | kofarnihon
# city not found. skipping....
# Processing Record 1 of Set 11 | katangli
# Processing Record 2 of Set 11 | azimur
# city not found. skipping....
# Processing Record 3 of Set 11 | may pen
# Processing Record 4 of Set 11 | pangoa
# Processing Record 5 of Set 11 | nhulunbuy
# Processing Record 6 of Set 11 | ayan
# Processing Record 7 of Set 11 | folldal
# Processing Record 8 of Set 11 | waipawa
# Processing Record 9 of Set 11 | barawe
# city not found. skipping....
# Processing Record 10 of Set 11 | ivanovka
# Processing Record 11 of Set 11 | korla
# Processing Record 12 of Set 11 | yantal
# Processing Record 13 of Set 11 | jimeta
# Processing Record 14 of Set 11 | jumla
# Processing Record 15 of Set 11 | mahadday weyne
# city not found. skipping....
# Processing Record 16 of Set 11 | calabozo
# Processing Record 17 of Set 11 | crotone
# Processing Record 18 of Set 11 | mwinilunga
# Processing Record 19 of Set 11 | andevoranto
# city not found. skipping....
# Processing Record 20 of Set 11 | lompoc
# Processing Record 21 of Set 11 | da lat
# Processing Record 22 of Set 11 | emboscada
# Processing Record 23 of Set 11 | fuxin
# Processing Record 24 of Set 11 | anloga
# Processing Record 25 of Set 11 | satitoa
# city not found. skipping....
# Processing Record 26 of Set 11 | montepuez
# Processing Record 27 of Set 11 | belyy yar
# Processing Record 28 of Set 11 | kahului
# Processing Record 29 of Set 11 | renigunta
# Processing Record 30 of Set 11 | copiapo
# Processing Record 31 of Set 11 | sechura
# Processing Record 32 of Set 11 | marsh harbour
# Processing Record 33 of Set 11 | tuy hoa
# Processing Record 34 of Set 11 | jacareacanga
# Processing Record 35 of Set 11 | manzil tamim
# city not found. skipping....
# Processing Record 36 of Set 11 | cockburn harbour
# city not found. skipping....
# Processing Record 37 of Set 11 | nabisar
# Processing Record 38 of Set 11 | solana
# Processing Record 39 of Set 11 | lewistown
# Processing Record 40 of Set 11 | partizansk
# Processing Record 41 of Set 11 | suleja
# Processing Record 42 of Set 11 | geelong
# Processing Record 43 of Set 11 | yuzhno-yeniseyskiy
# city not found. skipping....
# Processing Record 44 of Set 11 | beringovskiy
# Processing Record 45 of Set 11 | babanusah
# city not found. skipping....
# Processing Record 46 of Set 11 | bom jesus
# Processing Record 47 of Set 11 | bonthe
# Processing Record 48 of Set 11 | saint-francois
# Processing Record 49 of Set 11 | mitsamiouli
# Processing Record 50 of Set 11 | koulamoutou
# Processing Record 1 of Set 12 | iqaluit
# Processing Record 2 of Set 12 | hambantota
# Processing Record 3 of Set 12 | ambilobe
# Processing Record 4 of Set 12 | beyneu
# Processing Record 5 of Set 12 | zerbst
# Processing Record 6 of Set 12 | pangody
# Processing Record 7 of Set 12 | kifri
# Processing Record 8 of Set 12 | santo domingo
# Processing Record 9 of Set 12 | dunedin
# Processing Record 10 of Set 12 | port hardy
# Processing Record 11 of Set 12 | mondlo
# Processing Record 12 of Set 12 | jiaohe
# Processing Record 13 of Set 12 | yenagoa
# Processing Record 14 of Set 12 | kurilsk
# Processing Record 15 of Set 12 | karmana
# city not found. skipping....
# Processing Record 16 of Set 12 | neiafu
# Processing Record 17 of Set 12 | rawson
# Processing Record 18 of Set 12 | tonneins
# Processing Record 19 of Set 12 | prince rupert
# Processing Record 20 of Set 12 | astoria
# Processing Record 21 of Set 12 | tunceli
# Processing Record 22 of Set 12 | saleaula
# city not found. skipping....
# Processing Record 23 of Set 12 | wamba
# Processing Record 24 of Set 12 | bahia de caraquez
# Processing Record 25 of Set 12 | sayyan
# Processing Record 26 of Set 12 | kastamonu
# Processing Record 27 of Set 12 | senno
# Processing Record 28 of Set 12 | los llanos de aridane
# Processing Record 29 of Set 12 | sedalia
# Processing Record 30 of Set 12 | mongo
# Processing Record 31 of Set 12 | mildura
# Processing Record 32 of Set 12 | kazalinsk
# city not found. skipping....
# Processing Record 33 of Set 12 | pedernales
# Processing Record 34 of Set 12 | quesnel
# Processing Record 35 of Set 12 | gambela
# Processing Record 36 of Set 12 | kuminskiy
# Processing Record 37 of Set 12 | nizhneyansk
# city not found. skipping....
# Processing Record 38 of Set 12 | floriano
# Processing Record 39 of Set 12 | kralendijk
# Processing Record 40 of Set 12 | changping
# Processing Record 41 of Set 12 | cantaura
# Processing Record 42 of Set 12 | kyshtovka
# Processing Record 43 of Set 12 | can
# Processing Record 44 of Set 12 | turka
# Processing Record 45 of Set 12 | lakatoro
# Processing Record 46 of Set 12 | dongtai
# Processing Record 47 of Set 12 | moerai
# Processing Record 48 of Set 12 | freeport
# Processing Record 49 of Set 12 | salice salentino
# Processing Record 50 of Set 12 | teguise
# Processing Record 1 of Set 13 | srednekolymsk
# Processing Record 2 of Set 13 | constitucion
# Processing Record 3 of Set 13 | kattivakkam
# Processing Record 4 of Set 13 | mursalimkino
# Processing Record 5 of Set 13 | solnechnyy
# Processing Record 6 of Set 13 | bata
# Processing Record 7 of Set 13 | salamanca
# Processing Record 8 of Set 13 | juneau
# Processing Record 9 of Set 13 | margate
# Processing Record 10 of Set 13 | samalaeulu
# city not found. skipping....
# Processing Record 11 of Set 13 | pancas
# Processing Record 12 of Set 13 | greystones
# Processing Record 13 of Set 13 | pak phanang
# Processing Record 14 of Set 13 | xian
# Processing Record 15 of Set 13 | muhos
# Processing Record 16 of Set 13 | warwick
# Processing Record 17 of Set 13 | nikel
# Processing Record 18 of Set 13 | shiyan
# Processing Record 19 of Set 13 | hamina
# Processing Record 20 of Set 13 | tukrah
# Processing Record 21 of Set 13 | xifeng
# Processing Record 22 of Set 13 | roros
# Processing Record 23 of Set 13 | mayo
# Processing Record 24 of Set 13 | sao jose da coroa grande
# Processing Record 25 of Set 13 | nuuk
# Processing Record 26 of Set 13 | putina
# Processing Record 27 of Set 13 | harihar
# Processing Record 28 of Set 13 | roxana
# Processing Record 29 of Set 13 | atar
# Processing Record 30 of Set 13 | bryan
# Processing Record 31 of Set 13 | kemin
# Processing Record 32 of Set 13 | camacha
# Processing Record 33 of Set 13 | shingu
# Processing Record 34 of Set 13 | bismarck
# Processing Record 35 of Set 13 | naze
# Processing Record 36 of Set 13 | volosovo
# Processing Record 37 of Set 13 | san ramon
# Processing Record 38 of Set 13 | novaya ladoga
# Processing Record 39 of Set 13 | marrakesh
# Processing Record 40 of Set 13 | store heddinge
# Processing Record 41 of Set 13 | marystown
# Processing Record 42 of Set 13 | linhares
# Processing Record 43 of Set 13 | dudinka
# Processing Record 44 of Set 13 | leh
# Processing Record 45 of Set 13 | tsilna
# Processing Record 46 of Set 13 | ternate
# Processing Record 47 of Set 13 | cairns
# Processing Record 48 of Set 13 | bayburt
# Processing Record 49 of Set 13 | mount gambier
# Processing Record 50 of Set 13 | dong hoi
# Processing Record 1 of Set 14 | arman
# Processing Record 2 of Set 14 | vero beach
# Processing Record 3 of Set 14 | rabaul
# Processing Record 4 of Set 14 | huarmey
# Processing Record 5 of Set 14 | dzhebariki-khaya
# Processing Record 6 of Set 14 | joigny
# Processing Record 7 of Set 14 | rocha
# Processing Record 8 of Set 14 | teya
# Processing Record 9 of Set 14 | cap malheureux
# Processing Record 10 of Set 14 | kroya
# Processing Record 11 of Set 14 | kasongo
# Processing Record 12 of Set 14 | alugan
# Processing Record 13 of Set 14 | mendahara
# city not found. skipping....
# Processing Record 14 of Set 14 | mindelo
# Processing Record 15 of Set 14 | two hills
# Processing Record 16 of Set 14 | novyy urengoy
# Processing Record 17 of Set 14 | akdagmadeni
# Processing Record 18 of Set 14 | sirfa
# city not found. skipping....
# Processing Record 19 of Set 14 | nyurba
# Processing Record 20 of Set 14 | klooga
# Processing Record 21 of Set 14 | lolua
# city not found. skipping....
# Processing Record 22 of Set 14 | vilyuysk
# Processing Record 23 of Set 14 | cocobeach
# Processing Record 24 of Set 14 | owando
# Processing Record 25 of Set 14 | selma
# Processing Record 26 of Set 14 | simi
# Processing Record 27 of Set 14 | tabou
# Processing Record 28 of Set 14 | manaus
# Processing Record 29 of Set 14 | cabedelo
# Processing Record 30 of Set 14 | lahaina
# Processing Record 31 of Set 14 | richmond
# Processing Record 32 of Set 14 | mawlaik
# Processing Record 33 of Set 14 | sabla
# Processing Record 34 of Set 14 | keshan
# city not found. skipping....
# Processing Record 35 of Set 14 | maine-soroa
# Processing Record 36 of Set 14 | taburao
# city not found. skipping....
# Processing Record 37 of Set 14 | arzakan
# Processing Record 38 of Set 14 | lorengau
# Processing Record 39 of Set 14 | bani walid
# Processing Record 40 of Set 14 | nantucket
# Processing Record 41 of Set 14 | hvide sande
# Processing Record 42 of Set 14 | carutapera
# Processing Record 43 of Set 14 | pala
# Processing Record 44 of Set 14 | kissidougou
# Processing Record 45 of Set 14 | whyalla
# Processing Record 46 of Set 14 | pundaguitan
# Processing Record 47 of Set 14 | karratha
# Processing Record 48 of Set 14 | willowmore
# Processing Record 49 of Set 14 | abu dhabi
# Processing Record 50 of Set 14 | belem de sao francisco
# Processing Record 1 of Set 15 | huamachuco
# Processing Record 2 of Set 15 | naftah
# city not found. skipping....
# Processing Record 3 of Set 15 | galiwinku
# city not found. skipping....
# Processing Record 4 of Set 15 | severnyy
# Processing Record 5 of Set 15 | portobelo
# Processing Record 6 of Set 15 | kiunga
# Processing Record 7 of Set 15 | charters towers
# Processing Record 8 of Set 15 | pochutla
# Processing Record 9 of Set 15 | wilmington
# Processing Record 10 of Set 15 | bloemfontein
# Processing Record 11 of Set 15 | baymak
# Processing Record 12 of Set 15 | necochea
# Processing Record 13 of Set 15 | pouembout
# Processing Record 14 of Set 15 | kesennuma
# city not found. skipping....
# Processing Record 15 of Set 15 | tisul
# Processing Record 16 of Set 15 | belmonte
# Processing Record 17 of Set 15 | mutsamudu
# city not found. skipping....
# Processing Record 18 of Set 15 | malwan
# city not found. skipping....
# Processing Record 19 of Set 15 | lafia
# Processing Record 20 of Set 15 | sandnessjoen
# Processing Record 21 of Set 15 | tabuk
# Processing Record 22 of Set 15 | neepawa
# Processing Record 23 of Set 15 | moose factory
# Processing Record 24 of Set 15 | prainha
# Processing Record 25 of Set 15 | les escoumins
# Processing Record 26 of Set 15 | harper
# Processing Record 27 of Set 15 | boke
# Processing Record 28 of Set 15 | cuxhaven
# Processing Record 29 of Set 15 | camana
# Processing Record 30 of Set 15 | lastoursville
# Processing Record 31 of Set 15 | salme
# Processing Record 32 of Set 15 | marsabit
# Processing Record 33 of Set 15 | toliary
# city not found. skipping....
# Processing Record 34 of Set 15 | townsville
# Processing Record 35 of Set 15 | ahipara
# Processing Record 36 of Set 15 | totness
# Processing Record 37 of Set 15 | letka
# Processing Record 38 of Set 15 | iranshahr
# Processing Record 39 of Set 15 | bundaberg
# Processing Record 40 of Set 15 | feijo
# Processing Record 41 of Set 15 | penzance
# Processing Record 42 of Set 15 | belaya gora
# Processing Record 43 of Set 15 | tawang
# Processing Record 44 of Set 15 | rehoboth
# Processing Record 45 of Set 15 | bosaso
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 679

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     49.48        97          24
# 1         Kapaa      US  22.0752 -159.3190     81.12        72           1
# 2      Zhireken      RU  52.8249  117.3076     42.76        92          19
# 3        Albany      US  42.6001  -73.9662     78.91        58         100
# 4       Ushuaia      AR -54.8000  -68.3000     31.62        95          26
# 5          Amga      RU  60.8953  131.9608     49.69        69          13
# 6        Atuona      PF  -9.8000 -139.0333     80.02        72         100
# 7         Arcos      BR -20.2819  -45.5394     77.97        48          11
# 8    Nikolskoye      RU  59.7035   30.7861     60.69        75          35
# 9  Puerto Ayora      EC  -0.7393  -90.3518     80.56        80          92
#
#    Wind Speed Current_Description
# 0        2.57          few clouds
# 1        1.99           clear sky
# 2        4.76          few clouds
# 3        4.90     overcast clouds
# 4        1.66    scattered clouds
# 5        2.10          few clouds
# 6       15.93     overcast clouds
# 7        2.51          few clouds
# 8        5.39    scattered clouds
# 9        8.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
